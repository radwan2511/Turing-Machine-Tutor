# %% [markdown]
# # **First Install Package From Github**

# %%
# !pip install "git+https://github.com/Turing-Machine-Tutor/Turing-Machine-Tutor.git@main"
# Out:
# Collecting git+https://github.com/Turing-Machine-Tutor/Turing-Machine-Tutor.git@multiTape_controller#egg
#   Cloning https://github.com/Turing-Machine-Tutor/Turing-Machine-Tutor.git (to revision multiTape_controller) to /tmp/pip-req-build-_8mys93l
#   Running command git clone --filter=blob:none --quiet https://github.com/Turing-Machine-Tutor/Turing-Machine-Tutor.git /tmp/pip-req-build-_8mys93l
#   Running command git checkout -b multiTape_controller --track origin/multiTape_controller
#   Switched to a new branch 'multiTape_controller'
#   Branch 'multiTape_controller' set up to track remote branch 'multiTape_controller' from 'origin'.
#   Resolved https://github.com/Turing-Machine-Tutor/Turing-Machine-Tutor.git to commit ccd7f9ffe31383ab3f9d60f071cb2d2dfc6138fa
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: TuringMachineLib
#   Building wheel for TuringMachineLib (pyproject.toml) ... done
#   Created wheel for TuringMachineLib: filename=TuringMachineLib-0.0.0-py3-none-any.whl size=42160 sha256=650d05d3be049c5efc74a3043494871287e4e8f174ebb438d96c318bc42089e3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r7vjb8bi/wheels/40/1f/f7/e83ac979be33902a2ea412d6a74bae4407e89e67d6e1b81e1b
# Successfully built TuringMachineLib
# Installing collected packages: TuringMachineLib
# Successfully installed TuringMachineLib-0.0.0

# %% [markdown]
# # **Imports: dont touch**

# %%
from turing_machine_tutor.TuringMachine import TuringMachine
from turing_machine_tutor.CombinedTuringMachine import CombinedTuringMachine
from turing_machine_tutor.machine_run_state import Machine_Run_State
from turing_machine_tutor.Next import Next
from turing_machine_tutor.MultiNext import MultiNext
from turing_machine_tutor.Call_Turing_Machine import Call_Turing_Machine
from turing_machine_tutor.IFTuringMachine import IFTuringMachine
from turing_machine_tutor.TuringMachineController import TuringMachineController
from turing_machine_tutor.MultiTapeTuringMachine import MultiTapeTuringMachine
from turing_machine_tutor.WhileTuringMachine import WhileTuringMachine
from turing_machine_tutor.ConcatenateTM import ConcatenateTM

controller = TuringMachineController()

# %% [markdown]
# # **For student**:

# %% [markdown]
# Your main goal viewing all the availabe challenges and choosing one to work on.
#
# You can do that using the controller:
#
# **You don't need to define the function and to do add_challenge, this is done  by the TA, this is here just for the demonstration.

# %%
def is_0n1n(s):
    if(len(s) < 2):
        return False
    elif(len(s) == 2 and s != "01"):
        return False
    elif(len(s) == 2 and s == "01"):
        return True
    st = s.split('01')
    if(len(st) != 2):
        return False
    if(len(st[0]) != len(st[1])):
        return False
    for i in st[0]:
        if i != '0':
            return False
    for i in st[1]:
        if i != '1':
            return False
    return True

controller.add_challenge("0n1n",{'0', '1'},"turing machine that accepts 0n1n",is_0n1n,{"02","01"});

controller.get_challenges()
# Out:
# current available challenges:
#
# [1]turing machine name: 0n1n
# description: turing machine that accepts 0n1n

# %% [markdown]
# You will choose which challenge you want to work on.
#
#  Lets assume you want to work on 0n1n, your goal is to build a turing machine which language is 0n1n
#
# You have 4 options:
#
# 1) Regular turing machine.
#
# 2) Combined turing machine.
#
# 3) Combined turing machine with while condition.
#
# 4) IF THEN ESLSE machine.

# %% [markdown]
# # **Option 1 - building a regular turing machine object**:

# %% [markdown]
# You need to use this format:
#
#
#     TuringMachine (
#
#     states:list<string>,
#
#     input_alphabet:list<string>,
#
#     tape_symbols:list<string>,
#
#     transitions:dict< tuple<string,string> , **next**>,
#
#     initial_state:string,
#
#     accept_states:list<string>
#
#     )
#
# **next is an object:
#
#     next(
#
#         state:string
#
#         symbol:string
#
#         action:string
#
#       )
#
#
#
# In the code bellow there is an example of building a regular turing machine:
#
# **For clarity, this turing machine does not accept the language a^n b^n, you need to build it by yourself

# %%
_0_pow_n_1_pow_n_TM = TuringMachine(
            states={'q0', 'q1', 'q2', 'q3', 'q4', 'q5'},
            input_alphabet={'0', '1'},
            tape_symbols={'0', '1', 'X', 'Y', 'B'},
            transitions={
                ('q0', '0'): Next('q1', 'X', 'R'),  # Step 1 change 0 to X
                ('q0', 'Y'): Next('q3', 'Y', 'R'),
                ('q1', '0'): Next('q1', '0', 'R'),
                ('q1', '1'): Next('q2', 'Y', 'L'),
                ('q1', 'Y'): Next('q1', 'Y', 'R'),
                ('q2', '0'): Next('q2', '0', 'L'),
                ('q2', 'X'): Next('q0', 'X', 'R'),
                ('q2', 'Y'): Next('q2', 'Y', 'L'),
                ('q3', 'Y'): Next('q3', 'Y', 'R'),
                ('q3', 'B'): Next('q4', 'B', 'L')
            },
            initial_state='q0',
            accept_states={'q4'},
            reject_states={'q5'}
        )

## after you build it you need to add it to the controller and give it the same name  that was given by the TA:

controller.add_turing_machine('0n1n', _0_pow_n_1_pow_n_TM)

# %% [markdown]
# ## Checking your TM.
#
# You have few options:

# %% [markdown]
# #1) Run
# You can run a given word on the machine and see if it accepts or not, like this:
#
# controller.run_turing_machine(machine_name:string , word:string)

# %%
mrs = controller.run_turing_machine('0n1n', '0000011111')
# Out:
# tape:= XXXXXYYYYYB
# accepted:= True
# state:= q4

# %% [markdown]
# **mrs is an object
#
# It displays the current run state of the machine, the machine's tape, the machine's head_position, and the machine's state ('q0', 'q1', etc.).
#
# **Note:** Don't get confused by the word "state". There is an object `machine_run_state` and a state like 'q0', 'q1', etc.
#
#
#     Machine_Run_State(
#
#         tape:list<string>
#         head_position:int
#         state:string
#
#     )

# %% [markdown]
# # 2) Visualize
#
# You can visualize a given word on the machine and see your machine coming to life, you can do it like this:
#
# controller.visualize(machine_name:string , word:string)

# %%
controller.visualize('0n1n',"000111")
# Out:
# X 0 0 1 1 1
#       ^
# State: q1 | Step: 4
# -------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-10439c125695> in <cell line: 1>()
# ----> 1 controller.visualize('0n1n',"000111")
#
# /usr/local/lib/python3.10/dist-packages/turing_machine_tutor/TuringMachineController.py in visualize(self, turing_name, input, delay)
#     125         steps = visualizer.run_and_visualize(input,5000)
#     126
# --> 127         self.display_steps_of_visualizer(steps,delay)
#     128
#     129
#
# /usr/local/lib/python3.10/dist-packages/turing_machine_tutor/TuringMachineController.py in display_steps_of_visualizer(self, steps, delay)
#     183                 clear_output(wait=True)
#     184                 continue
# --> 185             self.print_step(step,steps_counter,delay)
#     186             clear_output(wait=True)
#     187             steps_counter=steps_counter+1
#
# /usr/local/lib/python3.10/dist-packages/turing_machine_tutor/TuringMachineController.py in print_step(self, step, step_counter, delay)
#     208         print(state_step_info)
#     209         print('-' * (2 * len(step.tape) + 1))  # Separator line
# --> 210         time.sleep(delay)  # Pause for a short duration to visualize each step
#     211         #clear_output(wait=True)
#     212
#
# KeyboardInterrupt:

# %% [markdown]
# You can also delay the steps of the TM simply add delay number in seconds

# %%
controller.visualize('0n1n',"01",2)
# Out:
# X 1
#   ^
# State: q1 | Step: 2
# -----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3107b3bdb375> in <cell line: 1>()
# ----> 1 controller.visualize('0n1n',"01",2)
#
# /usr/local/lib/python3.10/dist-packages/turing_machine_tutor/TuringMachineController.py in visualize(self, turing_name, input, delay)
#     125         steps = visualizer.run_and_visualize(input,5000)
#     126
# --> 127         self.display_steps_of_visualizer(steps,delay)
#     128
#     129
#
# /usr/local/lib/python3.10/dist-packages/turing_machine_tutor/TuringMachineController.py in display_steps_of_visualizer(self, steps, delay)
#     183                 clear_output(wait=True)
#     184                 continue
# --> 185             self.print_step(step,steps_counter,delay)
#     186             clear_output(wait=True)
#     187             steps_counter=steps_counter+1
#
# /usr/local/lib/python3.10/dist-packages/turing_machine_tutor/TuringMachineController.py in print_step(self, step, step_counter, delay)
#     208         print(state_step_info)
#     209         print('-' * (2 * len(step.tape) + 1))  # Separator line
# --> 210         time.sleep(delay)  # Pause for a short duration to visualize each step
#     211         #clear_output(wait=True)
#     212
#
# KeyboardInterrupt:

# %% [markdown]
# # 3) Visualize step by step (debugging)
#
# You can visualize STEP BY STEP a given word on the machine and observe EACH STEP as much as you want. Hitting enter will proceed to the next step, and if you've had enough, you can type 'stop' to stop. You can do it like this:
#
#
# controller.visualize_step_by_step(machine_name:string , word:string)

# %%
controller.visualize_step_by_step('0n1n',"01")
# Out:
# reached accept state

# %% [markdown]
# # 4)Validate
#
# Validating your turing machine formally, and getting a feedback which tests you pass and which you failed.  You can do it like this:
#
# controller.validate_turing_machine(machine_name:string)

# %%
controller.validate_turing_machine('0n1n',is_0n1n)
# Out:
# testing on input: 0
# Validation failed for input: 0 , func returned: False TM returned: True
# False

# %%
# Assume the TA added this to the challenges
controller.validate_turing_machineTA('0n1n')

# %% [markdown]
# # Submitting
#
# When you have finished working on your machines and want to submit, just call the function submit from the controller, it will ask you for your ID and your work will be submitted.
#
# controller.submit()

# %%
controller.submit()

# %% [markdown]
# # **Option 2 - building a combined turing machine object**:
# If you have previously defined a Turing machine and you want to reuse it as a sub part of a bigger machine (concatenating machines).
#
# For example, let's say you want to make a Turing machine that gets as an input a word, the output will be converting the first encountered 0 to 1, and the first encountered 1 to 0.
#
# And you have previously implemented a machine that converts first encountered 0 to 1 and implemented a machine that converts first encountered 1 to 0.
#
# You can use these implementations again instead of starting all over like this:

# %% [markdown]
# ** don't forget to add it to the controller!!!!

# %%
simple_turing_machine_1 = TuringMachine(  # this machine converts first encountered 0 to 1
            states={'q0', 'q1', 'q2'},
            input_alphabet={'0', '1','2'},
            tape_symbols={'0', '1', 'B','2'},
            transitions={
                ('q0', '0'): Next('q1', '1', 'R'),  # if encountered 0 put 1 and move right
                ('q0', '1'): Next('q0', '1', 'R'),  # if encountered 1 just move right
                ('q0', 'B'): Next('q1', 'B', 'S'),  # if encountered 1 just move right
                ('q1', '0'): Next('q1', '0', 'S'),  # after reaching q1 don't do anything
                ('q1', '1'): Next('q1', '1', 'S'),  # after reaching q1 don't do anything
                ('q1', 'B'): Next('q1', 'B', 'S'),  # after reaching q1 don't do anything
            },
            initial_state='q0',
            accept_states={'q1'},
            reject_states={'q2'}
        )
simple_turing_machine_2 = TuringMachine(# this machine converts first encountered 1 to 0
            states={'q0', 'q1', 'q2'},
            input_alphabet={'0', '1'},
            tape_symbols={'0', '1', 'B'},
            transitions={
                ('q0', '0'): Next('q0', '0', 'R'),  # if encountered 0 just move right
                ('q0', '1'): Next('q1', '0', 'R'),  # if encountered 1 put 0 and move right
                ('q0', 'B'): Next('q1', 'B', 'S'),
                ('q1', '0'): Next('q1', '0', 'S'),  # after reaching q1 don't do anything
                ('q1', '1'): Next('q1', '1', 'S'),  # after reaching q1 don't do anything
                ('q1', 'B'): Next('q1', 'B', 'S'),  # after reaching q1 don't do anything

            },
            initial_state='q0',
            accept_states={'q1'},
            reject_states={'q2'}
        )

combined_tm = CombinedTuringMachine({'0', '1'})
combined_tm.add("step1", simple_turing_machine_1)
combined_tm.add("step2", simple_turing_machine_2)

####################important step!!!! dont forget!!!##########################
controller.add_turing_machine('MyCombined',combined_tm)
###############################################################################

# %% [markdown]
# Or You Can use the ConcatenateTM

# %%
cont = ConcatenateTM("step1",simple_turing_machine_1, "step2", simple_turing_machine_2 )
controller.add_turing_machine('MyCont',combined_tm)

# %% [markdown]
# ## You Can Run, Visualize, and Check your combined TM.
#
# Excatly like the regular turing machine.

# %%
controller.run_turing_machine('MyCombined', "000111")
# Out:
# tape:= 100011
# accepted:= True
# state:= q1

# %%
controller.run_turing_machine('MyCont', "000111")
# Out:
# tape:= 100011
# accepted:= True
# state:= q1

# %%
controller.visualize('MyCombined',"111000111")
# Out:
# reached accept state

# %%
controller.visualize_step_by_step('MyCont',"111000111")
# Out:
# reached accept state

# %% [markdown]
# # **Option 3 - building a combined turing machine with while condition**:

# %% [markdown]
# Let's assume you want to implement a Turing machine that repeats specific steps until a certain condition is met. Achieving this in a regular or combined Turing machine can be sophisticated or impossible. You can approach this by:
#
# 1.   Defining regular Turing machines for each step.
# 2.   Defining a combined machine and adding steps to it.
# 3.   Defining a regular machine for the while condition.
#
# For example, let's assume you want to make a Turing machine whose language is 0^n 1^n

# %%
# language 0^n_1^n_2_0^n_1^n (2_0^n_1^n_2_0^n_1^n)*
step1 = TuringMachine(
            states={'q0', 'q1', 'q2', 'q3', 'q4', 'q5'},
            input_alphabet={'0', '1', '2', 'X', 'Y', 'B','Z'},
            tape_symbols={'0', '1', '2', 'X', 'Y', 'B','Z'},
            transitions={
                ('q0', '0'): Next('q1', 'X', 'R'),  # Step 1 change 0 to X
                ('q0', 'Y'): Next('q3', 'Y', 'R'),
                ('q1', '0'): Next('q1', '0', 'R'),
                ('q1', '1'): Next('q2', 'Y', 'L'),
                ('q1', 'Y'): Next('q1', 'Y', 'R'),
                ('q2', '0'): Next('q2', '0', 'L'),
                ('q2', 'X'): Next('q0', 'X', 'R'),
                ('q2', 'Y'): Next('q2', 'Y', 'L'),
                ('q3', 'Y'): Next('q3', 'Y', 'R'),
                ('q3', 'B'): Next('q4', 'B', 'S'),

                ('q3', '2'): Next('q4', '2', 'S')
            },
            initial_state='q0',
            accept_states={'q4'},
            reject_states={'q5'}
        )
cond = TuringMachine( #current head pos equals 0
            states={'q0', 'q1', 'q2', 'q3'},
            input_alphabet={'0', '1','2' , 'X', 'Y', 'B','Z'},
            tape_symbols={'0', '1','2', 'X', 'Y', 'B','Z'},
            transitions={
                ('q0', 'X'): Next('q0', 'X', 'R'),
                ('q0', 'Y'): Next('q0', 'Y', 'R'),
                ('q0', '2'): Next('q2', 'Z', 'R'),
                ('q0', 'Z'): Next('q0', 'Z', 'R')
            },
            initial_state='q0',
            accept_states={'q2'},
            reject_states={'q3'}
        )

# %% [markdown]
# This is equivalent to:
#
#     do
#     {
#               step1
#               step2
#               step3
#               step4
#
#     } while(while_condition_machine)

# %% [markdown]
# Combined all the steps in one machine:

# %%
combined_tm = CombinedTuringMachine({'0', '1', '2'})
combined_tm.add('find_a_n_b_n', step1)
#combined_tm.add('Move Left to Leftmost 0', step4)

#you want to repeat steps number 01 until no more 2 remain in the tape
combined_tm.setTuringMachineWhileCondition("2 still in tape", cond)
####################important step!!!! dont forget!!!##########################
controller.add_turing_machine('WhileCombined',combined_tm)
###############################################################################

# %% [markdown]
# You Can Also use WhileTuringMachine which is equivalent to while loop

# %%
cond = TuringMachine( # 1 occurences in tape is more than 2
            states={'q0', 'q1', 'qa', 'qr'},
            input_alphabet={'0', '1'},
            tape_symbols={'0', '1', 'B'},
            transitions={
                ('q0', '0'): Next('q0', '0', 'R'),
                ('q0', '1'): Next('q1', '1', 'R'),
                ('q0', 'B'): Next('qr', 'B', 'S'),
                ('q1', '0'): Next('q0', '0', 'R'),
                ('q1', '1'): Next('qa', '1', 'R'),
                ('q1', 'B'): Next('qr', 'B', 'S'),
            },
            initial_state='q0',
            accept_states={'qa'},
            reject_states={'qr'}
        )
do = TuringMachine( # replace the first 1 to 0
            states={'q0', 'q1', 'qa', 'qr'},
            input_alphabet={'0', '1'},
            tape_symbols={'0', '1', 'B'},
            transitions={
                ('q0', '0'): Next('q0', '0', 'R'),
                ('q0', '1'): Next('qa', '0', 'R'),
                ('q0', 'B'): Next('qr', 'B', 'S')
            },
            initial_state='q0',
            accept_states={'qa'},
            reject_states={'qr'}
        )

whileTM = WhileTuringMachine("1 occurences in tape is more than 2", cond, "replace 1 to 0", do)
controller.add_turing_machine("whileTM", whileTM)

# %% [markdown]
# ## You Can Run, Visualize, and Check your combined TM with While Condition.
#
# Excatly like it was described previously.

# %%
controller.run_turing_machine('WhileCombined', "001120011")
# Out:
# tape:= XXYYZXXYYB
# accepted:= True
# state:= q4

# %%
controller.run_turing_machine('whileTM', "1011001")
# Out:
# TM Cond rejected the input: 0001001
# tape:= 0001001
# accepted:= True
# state:= qa

# %%
controller.visualize('WhileCombined',"01201")
# Out:
# turing machine halted at non accepting state

# %%
controller.visualize('whileTM', "1011001")
# Out:
# reached accept state

# %% [markdown]
# Notice that the word is accepted only if the last TM in the Combined Accepts it, and The Combined TM with While Condition will halt when the While Condition TM Rejects the input. (as long as it accepts the input it will continue to iterate through the combined list)

# %%
def checkMyWhileCombined(input_str):
    if(len(input_str) == 0):
      return False
    if('2' in input_str):
      l = input_str.split('2')
      for i in l:
        if not is_0n1n(i):
          return False
    else:
      result = is_0n1n(input_str)
      if result:
        return True
      else:
        return False

controller.validate_turing_machine('WhileCombined', checkMyWhileCombined)

# %% [markdown]
# # **Option 4 - building an IF turing machine**:

# %% [markdown]
# You can create if then else statment using IFTuringMachine, example:
#
# If you want to make a turing machine that does the following: if the input length is < 4 change every 0 to 1 otherwise change every 1 to 0.
#
# You can implement that easly using the object IFTuringMachine:

# %%
ifTm = TuringMachine( # condition if input legth is less than 4 accept else reject
    states={'q0', 'q1', 'q2', 'q3', 'q4', 'q5', 'q6'},
    input_alphabet={'0', '1'},
    tape_symbols={'0', '1', 'B'},
    transitions={
        ('q0', '0'): Next('q1', '0', 'R'),
        ('q0', '1'): Next('q1', '1', 'R'),

        ('q1', '0'): Next('q2', '0', 'R'),
        ('q1', '1'): Next('q2', '1', 'R'),

        ('q2', '0'): Next('q3', '0', 'R'),
        ('q2', '1'): Next('q3', '0', 'R'),

        ('q3', '0'): Next('q6', '0', 'R'),
        ('q3', '1'): Next('q6', '1', 'R'),
        ('q3', 'B'): Next('q5', 'B', 'S')
    },
    initial_state='q0',
    accept_states={'q5'},
    reject_states={'q6'}
)

thenTm = TuringMachine( # condition if input legth is less than 4 change every 1 to 0
    states={'q0', 'q1', 'q2'},
    input_alphabet={'0', '1'},
    tape_symbols={'0', '1', 'B'},
    transitions={
        ('q0', '0'): Next('q0', '0', 'R'),
        ('q0', '1'): Next('q0', '0', 'R'),
        ('q0', 'B'): Next('q1', 'B', 'R')
    },
    initial_state='q0',
    accept_states={'q1'},
    reject_states={'q2'}
)

elseTm = TuringMachine( # condition if input legth is less than 4 change every 0 to 1
    states={'q0', 'q1', 'q2'},
    input_alphabet={'0', '1'},
    tape_symbols={'0', '1', 'B'},
    transitions={
        ('q0', '0'): Next('q0', '1', 'R'),
        ('q0', '1'): Next('q0', '1', 'R'),
        ('q0', 'B'): Next('q1', 'B', 'R')
    },
    initial_state='q0',
    accept_states={'q1'},
    reject_states={'q2'}
)


CondTM = IFTuringMachine("myIf", ifTm,"mythen", thenTm, "myelse", elseTm)


controller.add_turing_machine("mycondTM", CondTM)

# %% [markdown]
# ## You Can Run, Visualize, and Check your IF TM.
#
# Excatly like it was described previously.

# %%
controller.run_turing_machine("mycondTM", "001") # input length less than 4
# Out:
# tape:= 000BB
# accepted:= True
# state:= q1

# %%
controller.run_turing_machine("mycondTM", "001011") # input length greater than 4
# Out:
# tape:= 111111BB
# accepted:= True
# state:= q1

# %%
controller.visualize("mycondTM", "001011")
# Out:
# reached accept state

# %% [markdown]
# # **Option 5 - building an Multi Tape turing machine**:

# %% [markdown]
# You can create multi tape turing machine with the option to call another multi tape turing machine and pass to them some of your tm tapes using MultiTapeTuringMachine, example:
#
# If you want to make a turing machine that does the following: copies the first tape to second tape and then call another tm on the second tape that will replace each 1 to 0 and each 0 to 1.
#
# Note: output of the TM is the last Tape
#
# You can implement that easly using the object MultiTapeTuringMachine:

# %%
tm1 = MultiTapeTuringMachine(
    states={'q0', 'q1', 'q2', 'qa', 'qr'},
    input_alphabet={'0', '1', 'X'},
    tape_alphabet={'0', '1', 'B', 'X'},
    transition_function= {
    # (current_state, tape1_symbol, tape2_symbol): (new_state, tape1_new_symbol, tape2_new_symbol, direction1, direction2)
    ('q0', '0'): MultiNext('q1', '0', 'L'),
    ('q0', '1'): MultiNext('q1',  '1', 'L'),
    ('q0', 'B'): MultiNext('q1',  'B', 'L'),
    ('q1', '0'): MultiNext('q1', '0', 'L'),
    ('q1', '1'): MultiNext('q1',  '1', 'L'),
    ('q1', 'X'): MultiNext('qa',  'X', 'R')
},
    start_state='q0',
    accept_state={'qa'},
    reject_state={'qr'},
    num_tapes=1
)

tm2 = MultiTapeTuringMachine(
    states={'q0', 'q1', 'q2', 'qa', 'qr'},
    input_alphabet={'0', '1', 'X'},
    tape_alphabet={'0', '1', 'B', 'X'},
    transition_function= {
    # (current_state, tape1_symbol, tape2_symbol): (new_state, tape1_new_symbol, tape2_new_symbol, direction1, direction2)
    ('q0', '0'): MultiNext('q0', '1', 'R'),
    ('q0', '1'): MultiNext('q0',  '0', 'R'),
    ('q0', 'B'): MultiNext('qa',  'B', 'S')
},
    start_state='q0',
    accept_state={'qa'},
    reject_state={'qr'},
    num_tapes=1
)

tm3 = MultiTapeTuringMachine(
    states={'qs', 'q0', 'q1', 'q2', 'q3', 'qa', 'qr'},
    input_alphabet={'0', '1'},
    tape_alphabet={'0', '1', 'B', 'X'},
    transition_function= {
    # (current_state, tape1_symbol, tape2_symbol): (new_state, tape1_new_symbol, tape2_new_symbol, direction1, direction2)
    ('qs', '0', 'B'): MultiNext('q0', '0', 'X', 'S', 'R'),
    ('qs', '1', 'B'): MultiNext('q0', '1', 'X', 'S', 'R'),
    ('qs', 'B', 'B'): MultiNext('qa', 'B', 'B', 'S', 'S'),

    ('q0', '0', 'B'): MultiNext('q1', '0', '0', 'R', 'R'),
    ('q0', '1', 'B'): MultiNext('q1', '1', '1', 'R', 'R'),
    ('q0', 'B', 'B'): MultiNext('qa', 'B', 'B', 'S', 'S'),

    ('q1', '0', 'B'): MultiNext('q1', '0', '0', 'R', 'R'),
    ('q1', '1', 'B'): MultiNext('q1', '1', '1', 'R', 'R'),
    ('q1', 'B', 'B'): MultiNext('q2', 'B', 'B', 'S', 'S'),
    ('q2', 'B', 'B') : Call_Turing_Machine("move left on tape 2", tm1, [1], 'q3', 'qr'),

    ('q3', 'B', '0') : Call_Turing_Machine("replace 0 and 1", tm2, [1], 'qa', 'qr'),
    ('q3', 'B', '1') : Call_Turing_Machine("replace 0 and 1", tm2, [1], 'qa', 'qr')
},
    start_state='qs',
    accept_state={'qa'},
    reject_state={'qr'},
    num_tapes=2
)

controller.update_turing_machine("multi", tm3)

# %% [markdown]
# ## You Can Run, Visualize, and Check your MultiTape TM.
#
# Excatly like it was described previously.

# %%
inputs = ['1101', '']
controller.run_turing_machine("multi", inputs)
# Out:
# TM: move left on tape 2
# Result: Accepted
# Final Tapes:
# Tape 1: X1101B
# state: qa
# ----------------------------
# TM: replace 0 and 1
# Result: Accepted
# Final Tapes:
# Tape 1: X0010B
# state: qa
# ----------------------------
# TM: multi
# Result: Accepted
# Final Tapes:
# Tape 1: 1101B
# Tape 2: X0010B
# state: qa
# ----------------------------
# tape:= X0010B
# accepted:= True
# state:= qa

# %%
controller.visualize("multi", inputs)
# Out:
# Turing Machine Halted

# %%
controller.visualize_step_by_step("multi", inputs)
# Out:
# Tape 1: 1101B
#          ^
# Tape 2: X1B
#           ^
# Current State: q1
#
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-a1418a953f58> in <cell line: 1>()
# ----> 1 controller.visualize_step_by_step("multi", inputs)
#
# /usr/local/lib/python3.10/dist-packages/turing_machine_tutor/TuringMachineController.py in visualize_step_by_step(self, turing_name, machine_input)
#     147             if(step_counter==-1):
#     148                 return
# --> 149             user_input = input("Press Enter to continue or type 'stop' to end: ")
#     150             #clear_output(wait=True)
#     151             index=index+1
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## You Can Run, also validate your TM based on its output with string -> string function.

# %%
def binReplaceFunc(bin_str):
    res = ""
    if(bin_str == ""):
        return ""
    for x in bin_str:
        if x == "1":
            res += '0'
        elif x == "0":
            res += '1'
    return res


controller.add_challenge('replaceBin', {'0','1'}, "bin reaplacing 0 to 1 and 1 to 0", binReplaceFunc, {"111"})
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-28-93729d132643> in <cell line: 13>()
#      11
#      12
# ---> 13 controller.add_challenge('replaceBin', {'0','1'}, "bin reaplacing 0 to 1 and 1 to 0", binReplaceFunc, {"111"})
#
# /usr/local/lib/python3.10/dist-packages/turing_machine_tutor/TuringMachineController.py in add_challenge(self, turing_machine_name, input_alphabet, turing_machine_description, function_that_accepts_the_language_of_tm, edge_cases_list)
#     697         challenge = Challenge(turing_machine_name, input_alphabet, turing_machine_description, function_that_accepts_the_language_of_tm, edge_cases_list)
#     698         if(turing_machine_name in self.__challenges.keys()):
# --> 699             raise Exception("challenge with this name already exists")
#     700         self.__challenges[turing_machine_name] = challenge
#     701
#
# Exception: challenge with this name already exists

# %% [markdown]
# ## controller.add_turing_machine(TM_name, TM_object, "tape"/"bool")
# Turing Machine output type is "bool" by default you can also change it to tape.

# %%
tm3 = MultiTapeTuringMachine(
    states={'q0', 'q1', 'qa', 'qr'},
    input_alphabet={'0', '1'},
    tape_alphabet={'0', '1', 'B'},
    transition_function= {
    # (current_state, tape1_symbol, tape2_symbol): (new_state, tape1_new_symbol, tape2_new_symbol, direction1, direction2)
    ('q0', '0'): MultiNext('q0', '1', 'R'),
    ('q0', '1'): MultiNext('q0',  '0', 'R'),
    ('q0', 'B'): MultiNext('qa',  'B', 'L')
},
    start_state='q0',
    accept_state={'qa'},
    reject_state={'qr'},
    num_tapes=1
)

controller.add_turing_machine("replaceBin", tm3, "tape")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-29-4ae68c60da3a> in <cell line: 17>()
#      15 )
#      16
# ---> 17 controller.add_turing_machine("replaceBin", tm3, "tape")
#
# /usr/local/lib/python3.10/dist-packages/turing_machine_tutor/TuringMachineController.py in add_turing_machine(self, name, turing_machine, type)
#      55             raise Exception("Name cannot be not str object")
#      56         if(name in self.__turing_machines.keys()):
# ---> 57             raise Exception("Turing machine with this name already exists in the dict")
#      58         if(type != "bool" and type != "tape"):
#      59             raise Exception("Found error in Turing machine return type, should be bool or tape.")
#
# Exception: Turing machine with this name already exists in the dict

# %%
controller.run_turing_machine("replaceBin", "1")
# Out:
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0B
# state: qa
# ----------------------------
# tape:= 0B
# accepted:= True
# state:= qa

# %%
controller.visualize("replaceBin", ["111000"])
# Out:
# Turing Machine Halted

# %%
controller.validate_turing_machineTA("replaceBin")
# Out:
# Streaming output truncated to the last 5000 lines.
# Tape 1: 0000B
# state: qa
# ----------------------------
# Validation passed for input: 1111
# testing on input: 00101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11010B
# state: qa
# ----------------------------
# Validation passed for input: 00101
# testing on input: 001001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110110B
# state: qa
# ----------------------------
# Validation passed for input: 001001
# testing on input: 1000001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0111110B
# state: qa
# ----------------------------
# Validation passed for input: 1000001
# testing on input: 10011100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01100011B
# state: qa
# ----------------------------
# Validation passed for input: 10011100
# testing on input: 001100011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110011100B
# state: qa
# ----------------------------
# Validation passed for input: 001100011
# testing on input: 1010110100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0101001011B
# state: qa
# ----------------------------
# Validation passed for input: 1010110100
# testing on input: 11010010000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00101101111B
# state: qa
# ----------------------------
# Validation passed for input: 11010010000
# testing on input: 010011101000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101100010111B
# state: qa
# ----------------------------
# Validation passed for input: 010011101000
# testing on input: 1111000110001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0000111001110B
# state: qa
# ----------------------------
# Validation passed for input: 1111000110001
# testing on input: 01001000101001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10110111010110B
# state: qa
# ----------------------------
# Validation passed for input: 01001000101001
# testing on input: 000010110100100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 111101001011011B
# state: qa
# ----------------------------
# Validation passed for input: 000010110100100
# testing on input: 0101100100001100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1010011011110011B
# state: qa
# ----------------------------
# Validation passed for input: 0101100100001100
# testing on input: 00001111101010011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11110000010101100B
# state: qa
# ----------------------------
# Validation passed for input: 00001111101010011
# testing on input: 110101010011011011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001010101100100100B
# state: qa
# ----------------------------
# Validation passed for input: 110101010011011011
# testing on input: 0011110000010000001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1100001111101111110B
# state: qa
# ----------------------------
# Validation passed for input: 0011110000010000001
# testing on input: 0
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1B
# state: qa
# ----------------------------
# Validation passed for input: 0
# testing on input: 00
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11B
# state: qa
# ----------------------------
# Validation passed for input: 00
# testing on input: 011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100B
# state: qa
# ----------------------------
# Validation passed for input: 011
# testing on input: 1000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0111B
# state: qa
# ----------------------------
# Validation passed for input: 1000
# testing on input: 10011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01100B
# state: qa
# ----------------------------
# Validation passed for input: 10011
# testing on input: 010000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101111B
# state: qa
# ----------------------------
# Validation passed for input: 010000
# testing on input: 0010000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1101111B
# state: qa
# ----------------------------
# Validation passed for input: 0010000
# testing on input: 10111011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01000100B
# state: qa
# ----------------------------
# Validation passed for input: 10111011
# testing on input: 100110101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011001010B
# state: qa
# ----------------------------
# Validation passed for input: 100110101
# testing on input: 1111010001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0000101110B
# state: qa
# ----------------------------
# Validation passed for input: 1111010001
# testing on input: 00000010101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11111101010B
# state: qa
# ----------------------------
# Validation passed for input: 00000010101
# testing on input: 001010001000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110101110111B
# state: qa
# ----------------------------
# Validation passed for input: 001010001000
# testing on input: 1001011010101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0110100101010B
# state: qa
# ----------------------------
# Validation passed for input: 1001011010101
# testing on input: 00000001011010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11111110100101B
# state: qa
# ----------------------------
# Validation passed for input: 00000001011010
# testing on input: 100010011011111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011101100100000B
# state: qa
# ----------------------------
# Validation passed for input: 100010011011111
# testing on input: 1100001001001111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0011110110110000B
# state: qa
# ----------------------------
# Validation passed for input: 1100001001001111
# testing on input: 10010111111010001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01101000000101110B
# state: qa
# ----------------------------
# Validation passed for input: 10010111111010001
# testing on input: 011100010011000000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100011101100111111B
# state: qa
# ----------------------------
# Validation passed for input: 011100010011000000
# testing on input: 0100110000001101110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1011001111110010001B
# state: qa
# ----------------------------
# Validation passed for input: 0100110000001101110
# testing on input: 1
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0B
# state: qa
# ----------------------------
# Validation passed for input: 1
# testing on input: 00
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11B
# state: qa
# ----------------------------
# Validation passed for input: 00
# testing on input: 011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100B
# state: qa
# ----------------------------
# Validation passed for input: 011
# testing on input: 0101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1010B
# state: qa
# ----------------------------
# Validation passed for input: 0101
# testing on input: 01010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10101B
# state: qa
# ----------------------------
# Validation passed for input: 01010
# testing on input: 101100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 010011B
# state: qa
# ----------------------------
# Validation passed for input: 101100
# testing on input: 0111111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000000B
# state: qa
# ----------------------------
# Validation passed for input: 0111111
# testing on input: 00001110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11110001B
# state: qa
# ----------------------------
# Validation passed for input: 00001110
# testing on input: 010100000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101011111B
# state: qa
# ----------------------------
# Validation passed for input: 010100000
# testing on input: 0110011111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1001100000B
# state: qa
# ----------------------------
# Validation passed for input: 0110011111
# testing on input: 01101110100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10010001011B
# state: qa
# ----------------------------
# Validation passed for input: 01101110100
# testing on input: 011010100000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100101011111B
# state: qa
# ----------------------------
# Validation passed for input: 011010100000
# testing on input: 1101111101001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0010000010110B
# state: qa
# ----------------------------
# Validation passed for input: 1101111101001
# testing on input: 00110000101000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11001111010111B
# state: qa
# ----------------------------
# Validation passed for input: 00110000101000
# testing on input: 001001101101110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110110010010001B
# state: qa
# ----------------------------
# Validation passed for input: 001001101101110
# testing on input: 0111010011011111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000101100100000B
# state: qa
# ----------------------------
# Validation passed for input: 0111010011011111
# testing on input: 11011010101101100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00100101010010011B
# state: qa
# ----------------------------
# Validation passed for input: 11011010101101100
# testing on input: 010111100100011110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101000011011100001B
# state: qa
# ----------------------------
# Validation passed for input: 010111100100011110
# testing on input: 0000011100111111010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1111100011000000101B
# state: qa
# ----------------------------
# Validation passed for input: 0000011100111111010
# testing on input: 1
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0B
# state: qa
# ----------------------------
# Validation passed for input: 1
# testing on input: 10
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01B
# state: qa
# ----------------------------
# Validation passed for input: 10
# testing on input: 011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100B
# state: qa
# ----------------------------
# Validation passed for input: 011
# testing on input: 0011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1100B
# state: qa
# ----------------------------
# Validation passed for input: 0011
# testing on input: 01011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10100B
# state: qa
# ----------------------------
# Validation passed for input: 01011
# testing on input: 101111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 010000B
# state: qa
# ----------------------------
# Validation passed for input: 101111
# testing on input: 1101011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0010100B
# state: qa
# ----------------------------
# Validation passed for input: 1101011
# testing on input: 01101010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10010101B
# state: qa
# ----------------------------
# Validation passed for input: 01101010
# testing on input: 100000100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011111011B
# state: qa
# ----------------------------
# Validation passed for input: 100000100
# testing on input: 0010100100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1101011011B
# state: qa
# ----------------------------
# Validation passed for input: 0010100100
# testing on input: 11000111001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00111000110B
# state: qa
# ----------------------------
# Validation passed for input: 11000111001
# testing on input: 001111011011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110000100100B
# state: qa
# ----------------------------
# Validation passed for input: 001111011011
# testing on input: 0011000011001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1100111100110B
# state: qa
# ----------------------------
# Validation passed for input: 0011000011001
# testing on input: 10000110100111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01111001011000B
# state: qa
# ----------------------------
# Validation passed for input: 10000110100111
# testing on input: 100101100010001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011010011101110B
# state: qa
# ----------------------------
# Validation passed for input: 100101100010001
# testing on input: 1010001110101110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0101110001010001B
# state: qa
# ----------------------------
# Validation passed for input: 1010001110101110
# testing on input: 10000011011111100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01111100100000011B
# state: qa
# ----------------------------
# Validation passed for input: 10000011011111100
# testing on input: 011010110010011110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100101001101100001B
# state: qa
# ----------------------------
# Validation passed for input: 011010110010011110
# testing on input: 0001010000000010100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1110101111111101011B
# state: qa
# ----------------------------
# Validation passed for input: 0001010000000010100
# testing on input: 1
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0B
# state: qa
# ----------------------------
# Validation passed for input: 1
# testing on input: 01
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10B
# state: qa
# ----------------------------
# Validation passed for input: 01
# testing on input: 010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101B
# state: qa
# ----------------------------
# Validation passed for input: 010
# testing on input: 1000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0111B
# state: qa
# ----------------------------
# Validation passed for input: 1000
# testing on input: 10111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01000B
# state: qa
# ----------------------------
# Validation passed for input: 10111
# testing on input: 000011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 111100B
# state: qa
# ----------------------------
# Validation passed for input: 000011
# testing on input: 0111001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000110B
# state: qa
# ----------------------------
# Validation passed for input: 0111001
# testing on input: 01100000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10011111B
# state: qa
# ----------------------------
# Validation passed for input: 01100000
# testing on input: 100110000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011001111B
# state: qa
# ----------------------------
# Validation passed for input: 100110000
# testing on input: 1101101100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0010010011B
# state: qa
# ----------------------------
# Validation passed for input: 1101101100
# testing on input: 11000100110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00111011001B
# state: qa
# ----------------------------
# Validation passed for input: 11000100110
# testing on input: 100000011000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011111100111B
# state: qa
# ----------------------------
# Validation passed for input: 100000011000
# testing on input: 1111011011000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0000100100111B
# state: qa
# ----------------------------
# Validation passed for input: 1111011011000
# testing on input: 00111000101001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11000111010110B
# state: qa
# ----------------------------
# Validation passed for input: 00111000101001
# testing on input: 110000110010101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001111001101010B
# state: qa
# ----------------------------
# Validation passed for input: 110000110010101
# testing on input: 1101110010111000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0010001101000111B
# state: qa
# ----------------------------
# Validation passed for input: 1101110010111000
# testing on input: 10011010110001100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01100101001110011B
# state: qa
# ----------------------------
# Validation passed for input: 10011010110001100
# testing on input: 100111101100100110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011000010011011001B
# state: qa
# ----------------------------
# Validation passed for input: 100111101100100110
# testing on input: 1010100010101100001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0101011101010011110B
# state: qa
# ----------------------------
# Validation passed for input: 1010100010101100001
# testing on input: 1
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0B
# state: qa
# ----------------------------
# Validation passed for input: 1
# testing on input: 01
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10B
# state: qa
# ----------------------------
# Validation passed for input: 01
# testing on input: 010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101B
# state: qa
# ----------------------------
# Validation passed for input: 010
# testing on input: 1011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0100B
# state: qa
# ----------------------------
# Validation passed for input: 1011
# testing on input: 11011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00100B
# state: qa
# ----------------------------
# Validation passed for input: 11011
# testing on input: 011111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100000B
# state: qa
# ----------------------------
# Validation passed for input: 011111
# testing on input: 1011000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0100111B
# state: qa
# ----------------------------
# Validation passed for input: 1011000
# testing on input: 01111001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10000110B
# state: qa
# ----------------------------
# Validation passed for input: 01111001
# testing on input: 000010000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 111101111B
# state: qa
# ----------------------------
# Validation passed for input: 000010000
# testing on input: 0111010010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000101101B
# state: qa
# ----------------------------
# Validation passed for input: 0111010010
# testing on input: 10011101011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01100010100B
# state: qa
# ----------------------------
# Validation passed for input: 10011101011
# testing on input: 101100101010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 010011010101B
# state: qa
# ----------------------------
# Validation passed for input: 101100101010
# testing on input: 1011100101000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0100011010111B
# state: qa
# ----------------------------
# Validation passed for input: 1011100101000
# testing on input: 01010000110001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10101111001110B
# state: qa
# ----------------------------
# Validation passed for input: 01010000110001
# testing on input: 010000100000100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101111011111011B
# state: qa
# ----------------------------
# Validation passed for input: 010000100000100
# testing on input: 0111011001000001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000100110111110B
# state: qa
# ----------------------------
# Validation passed for input: 0111011001000001
# testing on input: 00101110010110111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11010001101001000B
# state: qa
# ----------------------------
# Validation passed for input: 00101110010110111
# testing on input: 110001101011001111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001110010100110000B
# state: qa
# ----------------------------
# Validation passed for input: 110001101011001111
# testing on input: 0000011111101011100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1111100000010100011B
# state: qa
# ----------------------------
# Validation passed for input: 0000011111101011100
# testing on input: 1
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0B
# state: qa
# ----------------------------
# Validation passed for input: 1
# testing on input: 01
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10B
# state: qa
# ----------------------------
# Validation passed for input: 01
# testing on input: 101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 010B
# state: qa
# ----------------------------
# Validation passed for input: 101
# testing on input: 0111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000B
# state: qa
# ----------------------------
# Validation passed for input: 0111
# testing on input: 01101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10010B
# state: qa
# ----------------------------
# Validation passed for input: 01101
# testing on input: 011100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100011B
# state: qa
# ----------------------------
# Validation passed for input: 011100
# testing on input: 1111110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0000001B
# state: qa
# ----------------------------
# Validation passed for input: 1111110
# testing on input: 00100011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11011100B
# state: qa
# ----------------------------
# Validation passed for input: 00100011
# testing on input: 110010011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001101100B
# state: qa
# ----------------------------
# Validation passed for input: 110010011
# testing on input: 1010011110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0101100001B
# state: qa
# ----------------------------
# Validation passed for input: 1010011110
# testing on input: 00100110110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11011001001B
# state: qa
# ----------------------------
# Validation passed for input: 00100110110
# testing on input: 110101100110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001010011001B
# state: qa
# ----------------------------
# Validation passed for input: 110101100110
# testing on input: 0110000111011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1001111000100B
# state: qa
# ----------------------------
# Validation passed for input: 0110000111011
# testing on input: 00011110010010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11100001101101B
# state: qa
# ----------------------------
# Validation passed for input: 00011110010010
# testing on input: 110001101110011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001110010001100B
# state: qa
# ----------------------------
# Validation passed for input: 110001101110011
# testing on input: 1101111011110011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0010000100001100B
# state: qa
# ----------------------------
# Validation passed for input: 1101111011110011
# testing on input: 10110001000110110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01001110111001001B
# state: qa
# ----------------------------
# Validation passed for input: 10110001000110110
# testing on input: 101100001011010001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 010011110100101110B
# state: qa
# ----------------------------
# Validation passed for input: 101100001011010001
# testing on input: 0010001110001001110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1101110001110110001B
# state: qa
# ----------------------------
# Validation passed for input: 0010001110001001110
# testing on input: 1
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0B
# state: qa
# ----------------------------
# Validation passed for input: 1
# testing on input: 10
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01B
# state: qa
# ----------------------------
# Validation passed for input: 10
# testing on input: 111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000B
# state: qa
# ----------------------------
# Validation passed for input: 111
# testing on input: 0111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000B
# state: qa
# ----------------------------
# Validation passed for input: 0111
# testing on input: 10010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01101B
# state: qa
# ----------------------------
# Validation passed for input: 10010
# testing on input: 110101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001010B
# state: qa
# ----------------------------
# Validation passed for input: 110101
# testing on input: 0111111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000000B
# state: qa
# ----------------------------
# Validation passed for input: 0111111
# testing on input: 01111100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10000011B
# state: qa
# ----------------------------
# Validation passed for input: 01111100
# testing on input: 001111000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110000111B
# state: qa
# ----------------------------
# Validation passed for input: 001111000
# testing on input: 0001100001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1110011110B
# state: qa
# ----------------------------
# Validation passed for input: 0001100001
# testing on input: 01111100010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10000011101B
# state: qa
# ----------------------------
# Validation passed for input: 01111100010
# testing on input: 001000101101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110111010010B
# state: qa
# ----------------------------
# Validation passed for input: 001000101101
# testing on input: 1110100110100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0001011001011B
# state: qa
# ----------------------------
# Validation passed for input: 1110100110100
# testing on input: 10110100111100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01001011000011B
# state: qa
# ----------------------------
# Validation passed for input: 10110100111100
# testing on input: 010110111101100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101001000010011B
# state: qa
# ----------------------------
# Validation passed for input: 010110111101100
# testing on input: 0100110000000001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1011001111111110B
# state: qa
# ----------------------------
# Validation passed for input: 0100110000000001
# testing on input: 00000100100111000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11111011011000111B
# state: qa
# ----------------------------
# Validation passed for input: 00000100100111000
# testing on input: 101101001001101100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 010010110110010011B
# state: qa
# ----------------------------
# Validation passed for input: 101101001001101100
# testing on input: 0101010001011110100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1010101110100001011B
# state: qa
# ----------------------------
# Validation passed for input: 0101010001011110100
# testing on input: 0
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1B
# state: qa
# ----------------------------
# Validation passed for input: 0
# testing on input: 00
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11B
# state: qa
# ----------------------------
# Validation passed for input: 00
# testing on input: 111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000B
# state: qa
# ----------------------------
# Validation passed for input: 111
# testing on input: 1011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0100B
# state: qa
# ----------------------------
# Validation passed for input: 1011
# testing on input: 00101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11010B
# state: qa
# ----------------------------
# Validation passed for input: 00101
# testing on input: 111111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000000B
# state: qa
# ----------------------------
# Validation passed for input: 111111
# testing on input: 1111101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0000010B
# state: qa
# ----------------------------
# Validation passed for input: 1111101
# testing on input: 11110001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00001110B
# state: qa
# ----------------------------
# Validation passed for input: 11110001
# testing on input: 001100000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110011111B
# state: qa
# ----------------------------
# Validation passed for input: 001100000
# testing on input: 0100011001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1011100110B
# state: qa
# ----------------------------
# Validation passed for input: 0100011001
# testing on input: 01111110000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10000001111B
# state: qa
# ----------------------------
# Validation passed for input: 01111110000
# testing on input: 000100101001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 111011010110B
# state: qa
# ----------------------------
# Validation passed for input: 000100101001
# testing on input: 0001100100111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1110011011000B
# state: qa
# ----------------------------
# Validation passed for input: 0001100100111
# testing on input: 10010100110010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01101011001101B
# state: qa
# ----------------------------
# Validation passed for input: 10010100110010
# testing on input: 010011100001111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101100011110000B
# state: qa
# ----------------------------
# Validation passed for input: 010011100001111
# testing on input: 1000011100011100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0111100011100011B
# state: qa
# ----------------------------
# Validation passed for input: 1000011100011100
# testing on input: 00110010101111110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11001101010000001B
# state: qa
# ----------------------------
# Validation passed for input: 00110010101111110
# testing on input: 000011001101000010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 111100110010111101B
# state: qa
# ----------------------------
# Validation passed for input: 000011001101000010
# testing on input: 0111011100000111010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000100011111000101B
# state: qa
# ----------------------------
# Validation passed for input: 0111011100000111010
# testing on input: 0
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1B
# state: qa
# ----------------------------
# Validation passed for input: 0
# testing on input: 00
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11B
# state: qa
# ----------------------------
# Validation passed for input: 00
# testing on input: 110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001B
# state: qa
# ----------------------------
# Validation passed for input: 110
# testing on input: 1010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0101B
# state: qa
# ----------------------------
# Validation passed for input: 1010
# testing on input: 01101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10010B
# state: qa
# ----------------------------
# Validation passed for input: 01101
# testing on input: 111110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000001B
# state: qa
# ----------------------------
# Validation passed for input: 111110
# testing on input: 0101001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1010110B
# state: qa
# ----------------------------
# Validation passed for input: 0101001
# testing on input: 01110001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10001110B
# state: qa
# ----------------------------
# Validation passed for input: 01110001
# testing on input: 111110101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000001010B
# state: qa
# ----------------------------
# Validation passed for input: 111110101
# testing on input: 1010111101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0101000010B
# state: qa
# ----------------------------
# Validation passed for input: 1010111101
# testing on input: 11000001111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00111110000B
# state: qa
# ----------------------------
# Validation passed for input: 11000001111
# testing on input: 011100011101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100011100010B
# state: qa
# ----------------------------
# Validation passed for input: 011100011101
# testing on input: 1111001000100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0000110111011B
# state: qa
# ----------------------------
# Validation passed for input: 1111001000100
# testing on input: 01000000100110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10111111011001B
# state: qa
# ----------------------------
# Validation passed for input: 01000000100110
# testing on input: 111011010000001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000100101111110B
# state: qa
# ----------------------------
# Validation passed for input: 111011010000001
# testing on input: 1011001111110111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0100110000001000B
# state: qa
# ----------------------------
# Validation passed for input: 1011001111110111
# testing on input: 00111101110110110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11000010001001001B
# state: qa
# ----------------------------
# Validation passed for input: 00111101110110110
# testing on input: 010100000101010011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101011111010101100B
# state: qa
# ----------------------------
# Validation passed for input: 010100000101010011
# testing on input: 1101100111001100101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0010011000110011010B
# state: qa
# ----------------------------
# Validation passed for input: 1101100111001100101
# testing on input: 1
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0B
# state: qa
# ----------------------------
# Validation passed for input: 1
# testing on input: 00
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11B
# state: qa
# ----------------------------
# Validation passed for input: 00
# testing on input: 100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011B
# state: qa
# ----------------------------
# Validation passed for input: 100
# testing on input: 0000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1111B
# state: qa
# ----------------------------
# Validation passed for input: 0000
# testing on input: 00100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11011B
# state: qa
# ----------------------------
# Validation passed for input: 00100
# testing on input: 010001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101110B
# state: qa
# ----------------------------
# Validation passed for input: 010001
# testing on input: 0100101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1011010B
# state: qa
# ----------------------------
# Validation passed for input: 0100101
# testing on input: 01111001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10000110B
# state: qa
# ----------------------------
# Validation passed for input: 01111001
# testing on input: 010000011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101111100B
# state: qa
# ----------------------------
# Validation passed for input: 010000011
# testing on input: 1100011011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0011100100B
# state: qa
# ----------------------------
# Validation passed for input: 1100011011
# testing on input: 10011100110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01100011001B
# state: qa
# ----------------------------
# Validation passed for input: 10011100110
# testing on input: 100100110101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011011001010B
# state: qa
# ----------------------------
# Validation passed for input: 100100110101
# testing on input: 1001100101011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0110011010100B
# state: qa
# ----------------------------
# Validation passed for input: 1001100101011
# testing on input: 11001010000101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00110101111010B
# state: qa
# ----------------------------
# Validation passed for input: 11001010000101
# testing on input: 001000000001100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110111111110011B
# state: qa
# ----------------------------
# Validation passed for input: 001000000001100
# testing on input: 1101100100001011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0010011011110100B
# state: qa
# ----------------------------
# Validation passed for input: 1101100100001011
# testing on input: 00110000001100110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11001111110011001B
# state: qa
# ----------------------------
# Validation passed for input: 00110000001100110
# testing on input: 100100110101110010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011011001010001101B
# state: qa
# ----------------------------
# Validation passed for input: 100100110101110010
# testing on input: 1111010101000011010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0000101010111100101B
# state: qa
# ----------------------------
# Validation passed for input: 1111010101000011010
# testing on input: 0
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1B
# state: qa
# ----------------------------
# Validation passed for input: 0
# testing on input: 10
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01B
# state: qa
# ----------------------------
# Validation passed for input: 10
# testing on input: 110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001B
# state: qa
# ----------------------------
# Validation passed for input: 110
# testing on input: 1010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0101B
# state: qa
# ----------------------------
# Validation passed for input: 1010
# testing on input: 00001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11110B
# state: qa
# ----------------------------
# Validation passed for input: 00001
# testing on input: 101101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 010010B
# state: qa
# ----------------------------
# Validation passed for input: 101101
# testing on input: 1001111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0110000B
# state: qa
# ----------------------------
# Validation passed for input: 1001111
# testing on input: 01001011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10110100B
# state: qa
# ----------------------------
# Validation passed for input: 01001011
# testing on input: 011101110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100010001B
# state: qa
# ----------------------------
# Validation passed for input: 011101110
# testing on input: 1111110000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0000001111B
# state: qa
# ----------------------------
# Validation passed for input: 1111110000
# testing on input: 11011001010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00100110101B
# state: qa
# ----------------------------
# Validation passed for input: 11011001010
# testing on input: 010010000011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101101111100B
# state: qa
# ----------------------------
# Validation passed for input: 010010000011
# testing on input: 0101011011111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1010100100000B
# state: qa
# ----------------------------
# Validation passed for input: 0101011011111
# testing on input: 10110001110011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01001110001100B
# state: qa
# ----------------------------
# Validation passed for input: 10110001110011
# testing on input: 111100011110111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000011100001000B
# state: qa
# ----------------------------
# Validation passed for input: 111100011110111
# testing on input: 1111000010111001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0000111101000110B
# state: qa
# ----------------------------
# Validation passed for input: 1111000010111001
# testing on input: 11101010110100101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00010101001011010B
# state: qa
# ----------------------------
# Validation passed for input: 11101010110100101
# testing on input: 100000010100010100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011111101011101011B
# state: qa
# ----------------------------
# Validation passed for input: 100000010100010100
# testing on input: 0111101010110000110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000010101001111001B
# state: qa
# ----------------------------
# Validation passed for input: 0111101010110000110
# testing on input: 1
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0B
# state: qa
# ----------------------------
# Validation passed for input: 1
# testing on input: 01
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10B
# state: qa
# ----------------------------
# Validation passed for input: 01
# testing on input: 111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000B
# state: qa
# ----------------------------
# Validation passed for input: 111
# testing on input: 1100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0011B
# state: qa
# ----------------------------
# Validation passed for input: 1100
# testing on input: 11011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00100B
# state: qa
# ----------------------------
# Validation passed for input: 11011
# testing on input: 001001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110110B
# state: qa
# ----------------------------
# Validation passed for input: 001001
# testing on input: 1101011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0010100B
# state: qa
# ----------------------------
# Validation passed for input: 1101011
# testing on input: 00001011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11110100B
# state: qa
# ----------------------------
# Validation passed for input: 00001011
# testing on input: 111010010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000101101B
# state: qa
# ----------------------------
# Validation passed for input: 111010010
# testing on input: 1100101110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0011010001B
# state: qa
# ----------------------------
# Validation passed for input: 1100101110
# testing on input: 11101001110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00010110001B
# state: qa
# ----------------------------
# Validation passed for input: 11101001110
# testing on input: 101101011011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 010010100100B
# state: qa
# ----------------------------
# Validation passed for input: 101101011011
# testing on input: 0011011010000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1100100101111B
# state: qa
# ----------------------------
# Validation passed for input: 0011011010000
# testing on input: 11011011110101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00100100001010B
# state: qa
# ----------------------------
# Validation passed for input: 11011011110101
# testing on input: 101101011100000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 010010100011111B
# state: qa
# ----------------------------
# Validation passed for input: 101101011100000
# testing on input: 0010100111111000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1101011000000111B
# state: qa
# ----------------------------
# Validation passed for input: 0010100111111000
# testing on input: 01110111111010000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10001000000101111B
# state: qa
# ----------------------------
# Validation passed for input: 01110111111010000
# testing on input: 111010111010101100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000101000101010011B
# state: qa
# ----------------------------
# Validation passed for input: 111010111010101100
# testing on input: 1011111100001011100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0100000011110100011B
# state: qa
# ----------------------------
# Validation passed for input: 1011111100001011100
# testing on input: 0
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1B
# state: qa
# ----------------------------
# Validation passed for input: 0
# testing on input: 10
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01B
# state: qa
# ----------------------------
# Validation passed for input: 10
# testing on input: 001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110B
# state: qa
# ----------------------------
# Validation passed for input: 001
# testing on input: 0100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1011B
# state: qa
# ----------------------------
# Validation passed for input: 0100
# testing on input: 00101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11010B
# state: qa
# ----------------------------
# Validation passed for input: 00101
# testing on input: 100100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011011B
# state: qa
# ----------------------------
# Validation passed for input: 100100
# testing on input: 1011110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0100001B
# state: qa
# ----------------------------
# Validation passed for input: 1011110
# testing on input: 01101110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10010001B
# state: qa
# ----------------------------
# Validation passed for input: 01101110
# testing on input: 100110001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011001110B
# state: qa
# ----------------------------
# Validation passed for input: 100110001
# testing on input: 0010010111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1101101000B
# state: qa
# ----------------------------
# Validation passed for input: 0010010111
# testing on input: 00000011110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11111100001B
# state: qa
# ----------------------------
# Validation passed for input: 00000011110
# testing on input: 011010110000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100101001111B
# state: qa
# ----------------------------
# Validation passed for input: 011010110000
# testing on input: 1110100110010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0001011001101B
# state: qa
# ----------------------------
# Validation passed for input: 1110100110010
# testing on input: 00011010110011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11100101001100B
# state: qa
# ----------------------------
# Validation passed for input: 00011010110011
# testing on input: 111110010110010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000001101001101B
# state: qa
# ----------------------------
# Validation passed for input: 111110010110010
# testing on input: 1000110011001001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0111001100110110B
# state: qa
# ----------------------------
# Validation passed for input: 1000110011001001
# testing on input: 10011111000110110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01100000111001001B
# state: qa
# ----------------------------
# Validation passed for input: 10011111000110110
# testing on input: 001111111111000011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110000000000111100B
# state: qa
# ----------------------------
# Validation passed for input: 001111111111000011
# testing on input: 0011000000111101000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1100111111000010111B
# state: qa
# ----------------------------
# Validation passed for input: 0011000000111101000
# testing on input: 1
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0B
# state: qa
# ----------------------------
# Validation passed for input: 1
# testing on input: 00
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11B
# state: qa
# ----------------------------
# Validation passed for input: 00
# testing on input: 010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101B
# state: qa
# ----------------------------
# Validation passed for input: 010
# testing on input: 0011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1100B
# state: qa
# ----------------------------
# Validation passed for input: 0011
# testing on input: 01110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10001B
# state: qa
# ----------------------------
# Validation passed for input: 01110
# testing on input: 010010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101101B
# state: qa
# ----------------------------
# Validation passed for input: 010010
# testing on input: 1111001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0000110B
# state: qa
# ----------------------------
# Validation passed for input: 1111001
# testing on input: 10110111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01001000B
# state: qa
# ----------------------------
# Validation passed for input: 10110111
# testing on input: 110000111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001111000B
# state: qa
# ----------------------------
# Validation passed for input: 110000111
# testing on input: 1001001111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0110110000B
# state: qa
# ----------------------------
# Validation passed for input: 1001001111
# testing on input: 10001100100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01110011011B
# state: qa
# ----------------------------
# Validation passed for input: 10001100100
# testing on input: 010101010100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101010101011B
# state: qa
# ----------------------------
# Validation passed for input: 010101010100
# testing on input: 0101111010100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1010000101011B
# state: qa
# ----------------------------
# Validation passed for input: 0101111010100
# testing on input: 01010111110010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10101000001101B
# state: qa
# ----------------------------
# Validation passed for input: 01010111110010
# testing on input: 111010000000101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000101111111010B
# state: qa
# ...
# Final Tapes:
# Tape 1: 00011B
# state: qa
# ----------------------------
# Validation passed for input: 11100
# testing on input: 000101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 111010B
# state: qa
# ----------------------------
# Validation passed for input: 000101
# testing on input: 1101111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0010000B
# state: qa
# ----------------------------
# Validation passed for input: 1101111
# testing on input: 11100110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00011001B
# state: qa
# ----------------------------
# Validation passed for input: 11100110
# testing on input: 011110100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100001011B
# state: qa
# ----------------------------
# Validation passed for input: 011110100
# testing on input: 0101000101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1010111010B
# state: qa
# ----------------------------
# Validation passed for input: 0101000101
# testing on input: 11101011110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00010100001B
# state: qa
# ----------------------------
# Validation passed for input: 11101011110
# testing on input: 101011100010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 010100011101B
# state: qa
# ----------------------------
# Validation passed for input: 101011100010
# testing on input: 0110010000001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1001101111110B
# state: qa
# ----------------------------
# Validation passed for input: 0110010000001
# testing on input: 10001100011101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01110011100010B
# state: qa
# ----------------------------
# Validation passed for input: 10001100011101
# testing on input: 010011111000101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101100000111010B
# state: qa
# ----------------------------
# Validation passed for input: 010011111000101
# testing on input: 0111101001110000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000010110001111B
# state: qa
# ----------------------------
# Validation passed for input: 0111101001110000
# testing on input: 00011010011101011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11100101100010100B
# state: qa
# ----------------------------
# Validation passed for input: 00011010011101011
# testing on input: 010011000111100101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101100111000011010B
# state: qa
# ----------------------------
# Validation passed for input: 010011000111100101
# testing on input: 1011110110111110010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0100001001000001101B
# state: qa
# ----------------------------
# Validation passed for input: 1011110110111110010
# testing on input: 1
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0B
# state: qa
# ----------------------------
# Validation passed for input: 1
# testing on input: 01
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10B
# state: qa
# ----------------------------
# Validation passed for input: 01
# testing on input: 110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001B
# state: qa
# ----------------------------
# Validation passed for input: 110
# testing on input: 1110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0001B
# state: qa
# ----------------------------
# Validation passed for input: 1110
# testing on input: 00000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11111B
# state: qa
# ----------------------------
# Validation passed for input: 00000
# testing on input: 001000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110111B
# state: qa
# ----------------------------
# Validation passed for input: 001000
# testing on input: 0011000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1100111B
# state: qa
# ----------------------------
# Validation passed for input: 0011000
# testing on input: 10001100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01110011B
# state: qa
# ----------------------------
# Validation passed for input: 10001100
# testing on input: 010110011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101001100B
# state: qa
# ----------------------------
# Validation passed for input: 010110011
# testing on input: 0010010101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1101101010B
# state: qa
# ----------------------------
# Validation passed for input: 0010010101
# testing on input: 00101110100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11010001011B
# state: qa
# ----------------------------
# Validation passed for input: 00101110100
# testing on input: 101100010100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 010011101011B
# state: qa
# ----------------------------
# Validation passed for input: 101100010100
# testing on input: 1101001010010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0010110101101B
# state: qa
# ----------------------------
# Validation passed for input: 1101001010010
# testing on input: 10111101110111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01000010001000B
# state: qa
# ----------------------------
# Validation passed for input: 10111101110111
# testing on input: 100111000000101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011000111111010B
# state: qa
# ----------------------------
# Validation passed for input: 100111000000101
# testing on input: 0110010010010001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1001101101101110B
# state: qa
# ----------------------------
# Validation passed for input: 0110010010010001
# testing on input: 10001000101011010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01110111010100101B
# state: qa
# ----------------------------
# Validation passed for input: 10001000101011010
# testing on input: 110111000011011100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001000111100100011B
# state: qa
# ----------------------------
# Validation passed for input: 110111000011011100
# testing on input: 1011001110111101110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0100110001000010001B
# state: qa
# ----------------------------
# Validation passed for input: 1011001110111101110
# testing on input: 0
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1B
# state: qa
# ----------------------------
# Validation passed for input: 0
# testing on input: 10
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01B
# state: qa
# ----------------------------
# Validation passed for input: 10
# testing on input: 110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001B
# state: qa
# ----------------------------
# Validation passed for input: 110
# testing on input: 0011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1100B
# state: qa
# ----------------------------
# Validation passed for input: 0011
# testing on input: 01100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10011B
# state: qa
# ----------------------------
# Validation passed for input: 01100
# testing on input: 110110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001001B
# state: qa
# ----------------------------
# Validation passed for input: 110110
# testing on input: 0110101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1001010B
# state: qa
# ----------------------------
# Validation passed for input: 0110101
# testing on input: 00101100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11010011B
# state: qa
# ----------------------------
# Validation passed for input: 00101100
# testing on input: 100010110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 011101001B
# state: qa
# ----------------------------
# Validation passed for input: 100010110
# testing on input: 0001100111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1110011000B
# state: qa
# ----------------------------
# Validation passed for input: 0001100111
# testing on input: 00011000100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11100111011B
# state: qa
# ----------------------------
# Validation passed for input: 00011000100
# testing on input: 011111111000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100000000111B
# state: qa
# ----------------------------
# Validation passed for input: 011111111000
# testing on input: 1111110000110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0000001111001B
# state: qa
# ----------------------------
# Validation passed for input: 1111110000110
# testing on input: 00101010101110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11010101010001B
# state: qa
# ----------------------------
# Validation passed for input: 00101010101110
# testing on input: 110011001000110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001100110111001B
# state: qa
# ----------------------------
# Validation passed for input: 110011001000110
# testing on input: 0100011001011111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1011100110100000B
# state: qa
# ----------------------------
# Validation passed for input: 0100011001011111
# testing on input: 00011100101001000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11100011010110111B
# state: qa
# ----------------------------
# Validation passed for input: 00011100101001000
# testing on input: 001001100011100010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110110011100011101B
# state: qa
# ----------------------------
# Validation passed for input: 001001100011100010
# testing on input: 0111000010101110101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000111101010001010B
# state: qa
# ----------------------------
# Validation passed for input: 0111000010101110101
# testing on input: 0
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1B
# state: qa
# ----------------------------
# Validation passed for input: 0
# testing on input: 01
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 10B
# state: qa
# ----------------------------
# Validation passed for input: 01
# testing on input: 110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001B
# state: qa
# ----------------------------
# Validation passed for input: 110
# testing on input: 0001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1110B
# state: qa
# ----------------------------
# Validation passed for input: 0001
# testing on input: 10101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01010B
# state: qa
# ----------------------------
# Validation passed for input: 10101
# testing on input: 001010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110101B
# state: qa
# ----------------------------
# Validation passed for input: 001010
# testing on input: 0111101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1000010B
# state: qa
# ----------------------------
# Validation passed for input: 0111101
# testing on input: 11100001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00011110B
# state: qa
# ----------------------------
# Validation passed for input: 11100001
# testing on input: 000010100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 111101011B
# state: qa
# ----------------------------
# Validation passed for input: 000010100
# testing on input: 1101010100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0010101011B
# state: qa
# ----------------------------
# Validation passed for input: 1101010100
# testing on input: 10000010111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01111101000B
# state: qa
# ----------------------------
# Validation passed for input: 10000010111
# testing on input: 111000000111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000111111000B
# state: qa
# ----------------------------
# Validation passed for input: 111000000111
# testing on input: 0101011111110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1010100000001B
# state: qa
# ----------------------------
# Validation passed for input: 0101011111110
# testing on input: 11010100000110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00101011111001B
# state: qa
# ----------------------------
# Validation passed for input: 11010100000110
# testing on input: 001101001110101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 110010110001010B
# state: qa
# ----------------------------
# Validation passed for input: 001101001110101
# testing on input: 1110101110010010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0001010001101101B
# state: qa
# ----------------------------
# Validation passed for input: 1110101110010010
# testing on input: 10001000101000110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01110111010111001B
# state: qa
# ----------------------------
# Validation passed for input: 10001000101000110
# testing on input: 010111110110010011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101000001001101100B
# state: qa
# ----------------------------
# Validation passed for input: 010111110110010011
# testing on input: 1110010111011101101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 0001101000100010010B
# state: qa
# ----------------------------
# Validation passed for input: 1110010111011101101
# testing on input: 0
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1B
# state: qa
# ----------------------------
# Validation passed for input: 0
# testing on input: 11
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00B
# state: qa
# ----------------------------
# Validation passed for input: 11
# testing on input: 011
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 100B
# state: qa
# ----------------------------
# Validation passed for input: 011
# testing on input: 0010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1101B
# state: qa
# ----------------------------
# Validation passed for input: 0010
# testing on input: 00010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11101B
# state: qa
# ----------------------------
# Validation passed for input: 00010
# testing on input: 111100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000011B
# state: qa
# ----------------------------
# Validation passed for input: 111100
# testing on input: 0000000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1111111B
# state: qa
# ----------------------------
# Validation passed for input: 0000000
# testing on input: 00111100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11000011B
# state: qa
# ----------------------------
# Validation passed for input: 00111100
# testing on input: 000000000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 111111111B
# state: qa
# ----------------------------
# Validation passed for input: 000000000
# testing on input: 0011101010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1100010101B
# state: qa
# ----------------------------
# Validation passed for input: 0011101010
# testing on input: 10010100100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 01101011011B
# state: qa
# ----------------------------
# Validation passed for input: 10010100100
# testing on input: 010101000000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 101010111111B
# state: qa
# ----------------------------
# Validation passed for input: 010101000000
# testing on input: 0001010001010
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1110101110101B
# state: qa
# ----------------------------
# Validation passed for input: 0001010001010
# testing on input: 11110100110110
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 00001011001001B
# state: qa
# ----------------------------
# Validation passed for input: 11110100110110
# testing on input: 110000111000111
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 001111000111000B
# state: qa
# ----------------------------
# Validation passed for input: 110000111000111
# testing on input: 0100110000101000
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1011001111010111B
# state: qa
# ----------------------------
# Validation passed for input: 0100110000101000
# testing on input: 00101011010110101
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 11010100101001010B
# state: qa
# ----------------------------
# Validation passed for input: 00101011010110101
# testing on input: 101100011010101100
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 010011100101010011B
# state: qa
# ----------------------------
# Validation passed for input: 101100011010101100
# testing on input: 0010100001101100001
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 1101011110010011110B
# state: qa
# ----------------------------
# Validation passed for input: 0010100001101100001
# testing extreme cases:
#
# TM: replaceBin
# Result: Accepted
# Final Tapes:
# Tape 1: 000B
# state: qa
# ----------------------------
# Validation passed for input: 111
#
#
# all Validation passed for replaceBin Turing machine.
# True
